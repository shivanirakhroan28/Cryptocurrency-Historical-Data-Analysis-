# %%
import numpy as np
import pandas as pd

# %%
bitcoin = pd.read_csv(r"C:\Users\shivani\Downloads\bitcoin_price.csv")
bitcoin
# Out:
#               Date     Open     High      Low    Close         Volume  \
# 0     Nov 07, 2017  7023.10  7253.32  7023.10  7144.38  2,326,340,000
# 1     Nov 06, 2017  7403.22  7445.77  7007.31  7022.76  3,111,900,000
# 2     Nov 05, 2017  7404.52  7617.48  7333.19  7407.41  2,380,410,000
# 3     Nov 04, 2017  7164.48  7492.86  7031.28  7379.95  2,483,800,000
# 4     Nov 03, 2017  7087.53  7461.29  7002.94  7207.76  3,369,860,000
# ...            ...      ...      ...      ...      ...            ...
# 1650  May 02, 2013   116.38   125.60    92.28   105.21              -
# 1651  May 01, 2013   139.00   139.89   107.72   116.99              -
# 1652  Apr 30, 2013   144.00   146.93   134.05   139.00              -
# 1653  Apr 29, 2013   134.44   147.49   134.00   144.54              -
# 1654  Apr 28, 2013   135.30   135.98   132.10   134.21              -
#
#            Market Cap
# 0     117,056,000,000
# 1     123,379,000,000
# 2     123,388,000,000
# 3     119,376,000,000
# ...

# %%
ethereum=pd.read_csv(r"C:\Users\shivani\Downloads\ethereum_price.csv")
ethereum
# Out:
#              Date        Open        High         Low       Close  \
# 0    Nov 07, 2017  298.570000  304.840000  290.770000  294.660000
# 1    Nov 06, 2017  296.430000  305.420000  293.720000  298.890000
# 2    Nov 05, 2017  300.040000  301.370000  295.120000  296.260000
# 3    Nov 04, 2017  305.480000  305.480000  295.800000  300.470000
# 4    Nov 03, 2017  288.500000  308.310000  287.690000  305.710000
# ..            ...         ...         ...         ...         ...
# 819  Aug 11, 2015    0.708087    1.130000    0.663235    1.070000
# 820  Aug 10, 2015    0.713989    0.729854    0.636546    0.708448
# 821  Aug 09, 2015    0.706136    0.879810    0.629191    0.701897
# 822  Aug 08, 2015    2.790000    2.800000    0.714725    0.753325
# 823  Aug 07, 2015    2.830000    3.540000    2.520000    2.770000
#
#           Volume      Market Cap
# 0    5407,66,000  28,533,300,000
# 1    5793,59,000  28,322,700,000
# 2    3376,58,000  28,661,500,000
# 3    4164,79,000  29,175,300,000
# ...

# %%
litecoin=pd.read_csv(r"C:\Users\shivani\Downloads\litecoin_price.csv")

# %%
monero=pd.read_csv(r"C:\Users\shivani\Downloads\monero_price.csv")

# %%
neo=pd.read_csv(r"C:\Users\shivani\Downloads\neo_price.csv")

# %%
qtum=pd.read_csv(r"C:\Users\shivani\Downloads\qtum_price.csv")

# %%
ripple=pd.read_csv(r"C:\Users\shivani\Downloads\ripple_price.csv")

# %%
bitcoin.columns= bitcoin.columns.map(lambda x: str(x)+'_bit')
ethereum.columns= ethereum.columns.map(lambda x: str(x)+'_eth')
litecoin.columns= litecoin.columns.map(lambda x: str(x)+'_lit')
monero.columns= monero.columns.map(lambda x: str(x)+'_mon')
neo.columns= neo.columns.map(lambda x: str(x)+'_neo')
qtum.columns= qtum.columns.map(lambda x: str(x)+'_qtum')
ripple.columns= ripple.columns.map(lambda x: str(x)+'_ripple')

# %%
m1= pd.merge(bitcoin,ethereum,how="inner",left_on="Date_bit",right_on="Date_eth")
m2= pd.merge(m1,litecoin,how="inner",left_on="Date_bit",right_on="Date_lit")
m3= pd.merge(m2,monero,how="inner",left_on="Date_bit",right_on="Date_mon")
m4= pd.merge(m3,neo,how="inner",left_on="Date_bit",right_on="Date_neo")
m5= pd.merge(m4,qtum,how="inner",left_on="Date_bit",right_on="Date_qtum")
final= pd.merge(m5,ripple,how="inner",left_on="Date_bit",right_on="Date_ripple")

# %%
final
# Out:
#          Date_bit  Open_bit  High_bit  Low_bit  Close_bit     Volume_bit  \
# 0    Nov 07, 2017   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1    Nov 06, 2017   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2    Nov 05, 2017   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3    Nov 04, 2017   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4    Nov 03, 2017   7087.53   7461.29  7002.94    7207.76  3,369,860,000
# ..            ...       ...       ...      ...        ...            ...
# 163  May 28, 2017   2054.08   2267.34  2054.08    2155.80  1,147,140,000
# 164  May 27, 2017   2196.27   2260.20  1855.83    2038.87  1,700,480,000
# 165  May 26, 2017   2320.89   2573.79  2071.99    2202.42  1,763,480,000
# 166  May 25, 2017   2446.24   2763.71  2285.30    2304.98  2,406,700,000
# 167  May 24, 2017   2321.37   2523.72  2321.37    2443.64  1,725,380,000
#
#       Market Cap_bit      Date_eth  Open_eth  High_eth  ...  Close_qtum  \
# ...

# %%
final.shape
# Out:
# (168, 49)

# %%
final.head(1)
# Out:
#        Date_bit  Open_bit  High_bit  Low_bit  Close_bit     Volume_bit  \
# 0  Nov 07, 2017    7023.1   7253.32   7023.1    7144.38  2,326,340,000
#
#     Market Cap_bit      Date_eth  Open_eth  High_eth  ...  Close_qtum  \
# 0  117,056,000,000  Nov 07, 2017    298.57    304.84  ...       11.21
#
#    Volume_qtum Market Cap_qtum   Date_ripple Open_ripple  High_ripple  \
# 0  122,951,000     760,320,000  Nov 07, 2017    0.205103     0.211375
#
#    Low_ripple  Close_ripple  Volume_ripple Market Cap_ripple
# 0    0.203978      0.210354    114,073,000     7,902,920,000
#
# [1 rows x 49 columns]

# %%
close_price= ["Date_bit","Close_bit","Close_eth","Close_lit","Close_mon","Close_neo","Close_qtum","Close_ripple"]

# %%
final[close_price]
# Out:
#          Date_bit  Close_bit  Close_eth  Close_lit  Close_mon  Close_neo  \
# 0    Nov 07, 2017    7144.38     294.66      61.30      99.76  26.230000
# 1    Nov 06, 2017    7022.76     298.89      55.17     102.92  26.320000
# 2    Nov 05, 2017    7407.41     296.26      54.75      86.35  26.380000
# 3    Nov 04, 2017    7379.95     300.47      55.04      87.30  26.490000
# 4    Nov 03, 2017    7207.76     305.71      56.18      87.99  26.820000
# ..            ...        ...        ...        ...        ...        ...
# 163  May 28, 2017    2155.80     170.51      24.22      36.84   0.930106
# 164  May 27, 2017    2038.87     157.76      23.74      33.41   0.982348
# 165  May 26, 2017    2202.42     160.40      23.75      38.71   0.826549
# 166  May 25, 2017    2304.98     174.45      29.90      40.12   1.110000
# 167  May 24, 2017    2443.64     190.05      34.45      45.38   1.760000
#
#      Close_qtum  Close_ripple
# 0         11.21      0.210354
# ...

# %%
final.dtypes
# Out:
# Date_bit              object
# Open_bit             float64
# High_bit             float64
# Low_bit              float64
# Close_bit            float64
# Volume_bit            object
# Market Cap_bit        object
# Date_eth              object
# Open_eth             float64
# High_eth             float64
# Low_eth              float64
# Close_eth            float64
# Volume_eth            object
# Market Cap_eth        object
# Date_lit              object
# Open_lit             float64
# High_lit             float64
# Low_lit              float64
# Close_lit            float64
# Volume_lit            object
# Market Cap_lit        object
# Date_mon              object
# Open_mon             float64
# High_mon             float64
# Low_mon              float64
# Close_mon            float64
# Volume_mon            object
# Market Cap_mon        object
# Date_neo              object
# Open_neo             float64
# High_neo             float64
# Low_neo              float64
# ...

# %%
final['Date_bit']=pd.to_datetime(final['Date_bit'])
final['Date_eth']=pd.to_datetime(final['Date_eth'])
final['Date_lit']=pd.to_datetime(final['Date_lit'])
final['Date_mon']=pd.to_datetime(final['Date_mon'])
final['Date_neo']=pd.to_datetime(final['Date_neo'])
final['Date_qtum']=pd.to_datetime(final['Date_qtum'])
final['Date_ripple']=pd.to_datetime(final['Date_ripple'])

# %%
final.dtypes
# Out:
# Date_bit             datetime64[ns]
# Open_bit                    float64
# High_bit                    float64
# Low_bit                     float64
# Close_bit                   float64
# Volume_bit                   object
# Market Cap_bit               object
# Date_eth             datetime64[ns]
# Open_eth                    float64
# High_eth                    float64
# Low_eth                     float64
# Close_eth                   float64
# Volume_eth                   object
# Market Cap_eth               object
# Date_lit             datetime64[ns]
# Open_lit                    float64
# High_lit                    float64
# Low_lit                     float64
# Close_lit                   float64
# Volume_lit                   object
# Market Cap_lit               object
# Date_mon             datetime64[ns]
# Open_mon                    float64
# High_mon                    float64
# Low_mon                     float64
# Close_mon                   float64
# ...

# %%
final
# Out:
#       Date_bit  Open_bit  High_bit  Low_bit  Close_bit     Volume_bit  \
# 0   2017-11-07   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1   2017-11-06   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2   2017-11-05   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3   2017-11-04   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4   2017-11-03   7087.53   7461.29  7002.94    7207.76  3,369,860,000
# ..         ...       ...       ...      ...        ...            ...
# 163 2017-05-28   2054.08   2267.34  2054.08    2155.80  1,147,140,000
# 164 2017-05-27   2196.27   2260.20  1855.83    2038.87  1,700,480,000
# 165 2017-05-26   2320.89   2573.79  2071.99    2202.42  1,763,480,000
# 166 2017-05-25   2446.24   2763.71  2285.30    2304.98  2,406,700,000
# 167 2017-05-24   2321.37   2523.72  2321.37    2443.64  1,725,380,000
#
#       Market Cap_bit   Date_eth  Open_eth  High_eth  ...  Close_qtum  \
# ...

# %%
final["Date"]= final["Date_bit"].dt.date
final["Year"]= final["Date_bit"].dt.year
final["Month"]= final["Date_bit"].dt.month

# %%
final
# Out:
#       Date_bit  Open_bit  High_bit  Low_bit  Close_bit     Volume_bit  \
# 0   2017-11-07   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1   2017-11-06   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2   2017-11-05   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3   2017-11-04   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4   2017-11-03   7087.53   7461.29  7002.94    7207.76  3,369,860,000
# ..         ...       ...       ...      ...        ...            ...
# 163 2017-05-28   2054.08   2267.34  2054.08    2155.80  1,147,140,000
# 164 2017-05-27   2196.27   2260.20  1855.83    2038.87  1,700,480,000
# 165 2017-05-26   2320.89   2573.79  2071.99    2202.42  1,763,480,000
# 166 2017-05-25   2446.24   2763.71  2285.30    2304.98  2,406,700,000
# 167 2017-05-24   2321.37   2523.72  2321.37    2443.64  1,725,380,000
#
#       Market Cap_bit   Date_eth  Open_eth  High_eth  ...  Date_ripple  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
final.describe(include="all")
# Out:
#                    Date_bit     Open_bit     High_bit      Low_bit  \
# count                   168   168.000000   168.000000   168.000000
# unique                  NaN          NaN          NaN          NaN
# top                     NaN          NaN          NaN          NaN
# freq                    NaN          NaN          NaN          NaN
# mean    2017-08-15 12:00:00  3742.344762  3873.473631  3629.658929
# min     2017-05-24 00:00:00  1932.620000  2058.770000  1843.030000
# 25%     2017-07-04 18:00:00  2599.967500  2691.692500  2518.317500
# 50%     2017-08-15 12:00:00  3628.970000  3802.495000  3520.660000
# 75%     2017-09-26 06:00:00  4385.640000  4473.847500  4318.100000
# max     2017-11-07 00:00:00  7404.520000  7617.480000  7333.190000
# std                     NaN  1315.081245  1351.453845  1299.264344
#
#           Close_bit     Volume_bit   Market Cap_bit             Date_eth  \
# count    168.000000            168              168                  168
# ...

# %%
final
# Out:
#       Date_bit  Open_bit  High_bit  Low_bit  Close_bit     Volume_bit  \
# 0   2017-11-07   7023.10   7253.32  7023.10    7144.38  2,326,340,000
# 1   2017-11-06   7403.22   7445.77  7007.31    7022.76  3,111,900,000
# 2   2017-11-05   7404.52   7617.48  7333.19    7407.41  2,380,410,000
# 3   2017-11-04   7164.48   7492.86  7031.28    7379.95  2,483,800,000
# 4   2017-11-03   7087.53   7461.29  7002.94    7207.76  3,369,860,000
# ..         ...       ...       ...      ...        ...            ...
# 163 2017-05-28   2054.08   2267.34  2054.08    2155.80  1,147,140,000
# 164 2017-05-27   2196.27   2260.20  1855.83    2038.87  1,700,480,000
# 165 2017-05-26   2320.89   2573.79  2071.99    2202.42  1,763,480,000
# 166 2017-05-25   2446.24   2763.71  2285.30    2304.98  2,406,700,000
# 167 2017-05-24   2321.37   2523.72  2321.37    2443.64  1,725,380,000
#
#       Market Cap_bit   Date_eth  Open_eth  High_eth  ...  Date_ripple  \
# ...

# %%
final[close_price]
# Out:
#       Date_bit  Close_bit  Close_eth  Close_lit  Close_mon  Close_neo  \
# 0   2017-11-07    7144.38     294.66      61.30      99.76  26.230000
# 1   2017-11-06    7022.76     298.89      55.17     102.92  26.320000
# 2   2017-11-05    7407.41     296.26      54.75      86.35  26.380000
# 3   2017-11-04    7379.95     300.47      55.04      87.30  26.490000
# 4   2017-11-03    7207.76     305.71      56.18      87.99  26.820000
# ..         ...        ...        ...        ...        ...        ...
# 163 2017-05-28    2155.80     170.51      24.22      36.84   0.930106
# 164 2017-05-27    2038.87     157.76      23.74      33.41   0.982348
# 165 2017-05-26    2202.42     160.40      23.75      38.71   0.826549
# 166 2017-05-25    2304.98     174.45      29.90      40.12   1.110000
# 167 2017-05-24    2443.64     190.05      34.45      45.38   1.760000
#
#      Close_qtum  Close_ripple
# 0         11.21      0.210354
# 1         10.44      0.205990
# 2         10.13      0.202055
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.distplot(final['Close_bit'], bins=50)
# Out:
# <Axes: xlabel='Close_bit', ylabel='Density'>

# %%
sns.distplot(final['Close_eth'], bins=50)
# Out:
# <Axes: xlabel='Close_eth', ylabel='Density'>

# %%
sns.distplot(final['Close_lit'], bins=50)
# Out:
# <Axes: xlabel='Close_lit', ylabel='Density'>

# %%
sns.distplot(final['Close_mon'],bins=50)
# Out:
# <Axes: xlabel='Close_mon', ylabel='Density'>

# %%
sns.distplot(final['Close_neo'],bins=50)
# Out:
# <Axes: xlabel='Close_neo', ylabel='Density'>

# %%
sns.distplot(final['Close_qtum'],bins=50)
# Out:
# <Axes: xlabel='Close_qtum', ylabel='Density'>

# %%
sns.distplot(final['Close_ripple'],bins=50)
# Out:
# <Axes: xlabel='Close_ripple', ylabel='Density'>

# %%
d= final.corr(numeric_only=True)

# %%
sns.heatmap(d)
# Out:
# <Axes: >

# %%
plt.plot(final['Date_bit'], final['Close_bit'], label='Bitcoin')
plt.title('to analyse data ')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,5))
plt.plot(final['Date_bit'], final['Close_bit'], label='Bitcoin')
plt.plot(final['Date_bit'],final['Close_eth'],label='ethereum')
plt.plot(final['Date_bit'],final['Close_lit'],label='litecoin')
plt.plot(final['Date_bit'],final['Close_mon'],label='monero')
plt.plot(final['Date_bit'],final['Close_neo'],label='neo')
plt.plot(final['Date_bit'],final['Close_qtum'],label='qtum')
plt.plot(final['Date_bit'],final['Close_ripple'],label='ripple')
plt.title('To Analyse Data',fontsize=16,fontweight='bold')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
yearly=final.groupby("Year").mean(numeric_only=True)
yearly
# Out:
#          Open_bit     High_bit      Low_bit    Close_bit    Open_eth  \
# Year
# 2017  3742.344762  3873.473631  3629.658929  3770.698631  282.604524
#
#         High_eth     Low_eth   Close_eth   Open_lit   High_lit  ...  \
# Year                                                            ...
# 2017  293.734226  270.080238  283.217976  48.423988  50.540655  ...
#
#       Close_neo  Open_qtum  High_qtum  Low_qtum  Close_qtum  Open_ripple  \
# Year
# 2017   18.85932   10.41256  11.184405  9.605595   10.442679      0.22103
#
#       High_ripple  Low_ripple  Close_ripple     Month
# Year
# 2017     0.231255     0.20988      0.220376  7.988095
#
# [1 rows x 29 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(final.index, final['Close_bit'], marker='o',lw=1,markersize=3,markerfacecolor="red",color="black")
plt.title('Yearly Bitcoin Closing Price',fontsize=16,fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Closing Price')
plt.grid=True
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(final.index,final['Close_eth'],marker='s',lw=1,markersize=3,markerfacecolor="red",color="black")
plt.title('Yearly Ethereum Closing Price',fontsize=16,fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Closing Price')
plt.grid=True
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(final.index,final['Close_lit'],marker='o',lw=1,markersize=4,markerfacecolor="red",color="black")
plt.title('Yearly Litecoin Closing Price',fontsize=16,fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Closing price')
sns.set_style('whitegrid')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(final.index,final['Close_mon'],marker='o',lw=1,markersize=4,markerfacecolor="red",color="black")
plt.title('Yearly Monero Closing Price',fontsize=16,fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Closing price')
sns.set_style('ticks')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(final.index,final['Close_neo'],marker='o',lw=1,markersize=4,markerfacecolor="pink",color="darkblue")
plt.title('Yearly Neo Closing Price',fontsize=16,fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Closing price')
sns.set_style('ticks')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(final.index,final['Close_qtum'],marker='o',lw=1,markersize=4,markerfacecolor="pink",color="darkblue")
plt.title('Yearly Qtum closing price',fontsize=16,fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Closing price')
sns.set_style('ticks')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.set_style('whitegrid')
plt.plot(final.index, final['Close_bit'],marker='o',lw=1,markersize=3,markerfacecolor="red",color="black",label='Bitcoin')
plt.plot(final.index, final['Close_lit'], lw=1,color="black",label='Litecoin')
plt.plot(final.index, final['Close_eth'], lw=1,color="orange",label='Ethereum') 
plt.plot(final.index,final['Close_ripple'],lw=1,color="black",label='Ripple')
plt.plot(final.index,final['Close_mon'],lw=1,color="black",label='Monero')
plt.plot(final.index,final['Close_neo'],lw=1,color="red",label='Neo')
plt.plot(final.index,final['Close_qtum'],lw=1,color="green",label='Qtum')
plt.title('Yearly Closing Price of All',fontsize=16,fontweight='bold')
plt.xlabel('Year',fontsize=16,fontweight='bold')
plt.ylabel('Closing Price',fontsize=16,fontweight='bold')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
ax=sns.countplot(x='Month',data=final,palette='nipy_spectral_r')
plt.title('Months that occur more in Data',fontsize=17,fontweight=22)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.set_style('whitegrid')
final["Year"].hist(bins=10,color='red',alpha=0.70)
plt.title('Histogram of Years',fontsize=17,fontweight=22)
plt.xlabel('Year',fontweight='bold',fontsize=14)
plt.ylabel('Frequency',fontweight='bold',fontsize=14)
# Out:
# Text(0, 0.5, 'Frequency')
